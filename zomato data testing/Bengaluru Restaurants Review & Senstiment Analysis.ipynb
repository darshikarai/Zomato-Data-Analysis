# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from matplotlib import rcParams
# %matplotlib inline

import os
for dirname, _, filenames in os.walk('D:'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# D:adhar back.jpg
# D:adhar front.jpg
# D:barcode.jpg
# D:bil.jpg
# D:firefox.exe
# D:mpcstar_5.4_setup.exe
# D:Notepad++ v6.7.4.exe
# D:PlantsvsZombies.exe
# D:VirtualDJ Local Database v6.xml
# D:vlc-2.0.5-win32.exe
# D:wampserver2.2d-x32.exe
# D:zomato.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I2FB3FQ
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I2L7KK0
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I2NOJEP
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I2NYEJ2.aaaevilacharya
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I35ZYDS.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I42S7M2
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I4RDOC2.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I6G5Q3U
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I6KK6SR.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$I89HOVP.ppt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IAE6LYD
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IB9NLAB
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IBARYSW.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$ICKC7AX.mp3
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IF9MP1P
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IFNX6VM
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IGR6C0B
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IH3W91Y.pptx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IH9KRYM
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IIR7YXT
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IIVD9S5
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IJTVLYC
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IK33CZY.pdf
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IL4K0JG.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IMA6RDL.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$INJ021Z.ppt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IOIBG7I.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IOPVPRC.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IPTPD0E
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IQ40FZR.exe
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IQ6TCY6
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$ITH6GXX.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$ITYW7G4.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IV6XDO7.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IV9GL9J
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IW094O1.exe
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IXUBFTH
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IXWKV3H
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IY8ZB9L.pptx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$IYXTQHY.pptx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R35ZYDS.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R4RDOC2.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6KK6SR.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R89HOVP.ppt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RBARYSW.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RH3W91Y.pptx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RK33CZY.pdf
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RMA6RDL.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RNJ021Z.ppt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$ROIBG7I.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$ROPVPRC.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RQ40FZR.exe
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RTH6GXX.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RTYW7G4.twb
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RV6XDO7.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RW094O1.exe
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RY8ZB9L.pptx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RYXTQHY.pptx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\desktop.ini
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2FB3FQ\~$signment 1.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\apache-commons-logging.jar.zip
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\apache-commons.jar.zip
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\BinaryFilesToHadoopSequenceFile
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\binarytosequence.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\commons-logging-1.2-src.zip
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\commons-logging-api-1.1.1.jar.zip
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\imagedriver
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\ImageDuplicatesMapper
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\ImageDupsReducer
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\Sequence_File_ProblemStatement.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\commons-logging-api-1.1.1.jar\commons-logging-api-1.1.1.jar
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\auto_loan.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\blur1.jpg
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\credit_card_loan.bmp
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\flower.jpg
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\flower1.jpg
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\flower2.jpg
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\glow_blur.jpg
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\home_loan.jpg
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\personal_loan.gif
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\sleigh.jpg
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2L7KK0\images\images\threshold_blur.jpg
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Aditya & Vishal\Numpy Assignment\Assignment1.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Aditya & Vishal\Numpy Assignment\Assignment2.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Alok kumar aryan\Numpy Assignment\Assignment1.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Alok kumar aryan\Numpy Assignment\Assignment2.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Numpy Assignment by Sandhaya & Shubhanshi\Checked_Numpy Assignment 1 Sandhaya & Shubhanshi.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Numpy Assignment by Sandhaya & Shubhanshi\Checked_Numpy Assignment 2 Sandhaya & Shubhanshi.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\NumPy Harshit swantika Assignments\Checked_NumPy_Assignment1.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\NumPy Harshit swantika Assignments\NumPy_Assignment2.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Ruchi_Anudeepti_NUMPY\Numpy_Arrays_Assignment2.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Ruchi_Anudeepti_NUMPY\Numpy_Basics_Assignment1.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Ruchi_Anudeepti_NUMPY\~$mpy_Arrays_Assignment2.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Ruchi_Anudeepti_NUMPY\~$mpy_Basics_Assignment1.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Ruchi_Anudeepti_NUMPY\Assignment1\Assignment1.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R2NOJEP\Ruchi_Anudeepti_NUMPY\Assignment2\assignment2.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R42S7M2\CountersSample\citycount.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R42S7M2\CountersSample\Consumer_Complaints.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R42S7M2\CountersSample\counterdata.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R42S7M2\CountersSample\Custom Counters Problem Statement.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R42S7M2\CountersSample\inputdata.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R42S7M2\CountersSample\MyCounter.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R42S7M2\CountersSample\problemstatement.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R42S7M2\CountersSample\~$stom Counters Problem Statement.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\alpha_part.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\b90.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\b91.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\b92.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\gen.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\lab assignment 6.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\pa1.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\partitionercode.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\partitionercodedata.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\partitionerdataforageproblem.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\temperature.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\~$b assignment 6.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\ReduceJoinProgram\custs
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\ReduceJoinProgram\department1.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\ReduceJoinProgram\employeedata.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\ReduceJoinProgram\Joins Problem Statement.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\ReduceJoinProgram\probstate.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\ReduceJoinProgram\reduce.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\ReduceJoinProgram\ReduceJoin.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$R6G5Q3U\ReduceJoinProgram\txns
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\aadhar
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\b87.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\b90.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\b91.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\b92.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\city_approved.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\city_reject.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\lab assignment 4.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\lab assignment 5.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\partitionercode.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\partitionercodedata.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\partitionerdataforageproblem.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\state_reject.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\temp_part.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\Thumbs.db
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RAE6LYD\~$b assignment 4.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RB9NLAB\practical 4.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RB9NLAB\tem.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RB9NLAB\temperature.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RB9NLAB\temperature.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RB9NLAB\weather.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RB9NLAB\Weather.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RF9MP1P\lab assignment.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RF9MP1P\PA.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RFNX6VM\alphabets.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RFNX6VM\alphabets.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RFNX6VM\pa.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RFNX6VM\pa.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RFNX6VM\PRACTICAL3.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RGR6C0B\aadhar
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RGR6C0B\city_approved.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RGR6C0B\city_reject.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RGR6C0B\lab assignment 5.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RGR6C0B\state_reject.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RGR6C0B\temp_part.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RH9KRYM\WordCount.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RH9KRYM\wordcountproblem
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RH9KRYM\jars\jars\hadoop-common-2.2.0.jar
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RH9KRYM\jars\jars\hadoop-mapreduce-client-core-2.2.0.jar
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\agglomerative_clustering (1).py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Case1_for_DataPreprocessing.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\cv.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\data preprocessing _normalization.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\data_preprocessing_handle_missing values.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\decision tree1.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\diabetes_clustering.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\dtree_irisdataset.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Ensembles_AdaBoosting.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Ensembles_BaggingExample.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Ensembles_RandomForest_Example.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Ensembles_VotingClassifier_Example1.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\K-Means.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\kmeans_clustering.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\knn_classifier.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\linear_regression.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\linear_regression_DiabetesExample.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\load_iris_kmean.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\medical_data_decision tree.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\NaiveBayes_Classifier.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\PCA_iris.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\preprocessing (1).py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\preprocessing_onehot encoder.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Session1.ppt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\solver.png
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\SVM_Classifier_Examples.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\ChicagoCrimesReport.pdf
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\diabetes.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\iris.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\loan_small.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\medical_fever data.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\pima-indians-diabetes.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Session1.ppt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Titanic.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\airline_passengers.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\balance.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\Car_Dataset.xlsx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\diabetes.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\iris.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\K-Means.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\kmeans-sklearn.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\load_iris_kmean.py
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\loan_small.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\movie_metadata.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\pima-indians-diabetes.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\Project_DataSet.xlsx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\Sample_Dataset.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\shopping_data.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\sonar_mine.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\store_data.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\Titanic.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\titanic.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\Titanic1.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\Weather.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\winequalityN.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\NLP Datasets\test\test.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIR7YXT\Datasets\Datasets\NLP Datasets\train\train.csv
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Map side join\DistributedCache\abc.dat
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Map side join\DistributedCache\dcinput
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Map side join\DistributedCache\department1.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Map side join\DistributedCache\DistributedCache.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Map side join\DistributedCache\employeedata.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Map side join\DistributedCache\empmap.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Map side join\DistributedCache\MyDC.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Map side join\DistributedCache\ProblemStatement.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Map side join\DistributedCache\question.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Reduce side join\custs
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Reduce side join\department1.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Reduce side join\employeedata.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Reduce side join\empred.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Reduce side join\Joins Problem Statement.docx
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Reduce side join\probstate.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Reduce side join\reduce.txt
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Reduce side join\ReduceJoin.java
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RIVD9S5\Reduce side join\txns
# D:$RECYCLE.BIN\S-1-5-21-1409422892-845088586-3267756975-1001\$RJTVLYC
# D:New folder\CDAC documents\hostel.pdf
# D:New folder\CDAC documents\Proof_of_income.pdf
# D:New folder\CDAC documents\salary.pdf
# D:New folder\CDAC documents\salry statement (1) (1)_compressed.pdf
# D:New folder\CDAC documents\salry statement.pdf
# D:New folder\CDAC documents\sushil.pdf
# D:New folder\Projects\Chat_bot_by_sahil_ruchi\ChatBot\cbot.txt
# D:New folder\Projects\Chat_bot_by_sahil_ruchi\ChatBot\chatbot.py
# D:New folder\Projects\Chat_bot_by_sahil_ruchi\ChatBot\chathis.txt
# D:New folder\Projects\Chat_bot_by_sahil_ruchi\ChatBot\feed.csv
# D:New folder\Projects\Chat_bot_by_sahil_ruchi\Reading Material\cbot_PRINT.pdf
# D:New folder\Projects\Chat_bot_by_sahil_ruchi\Reading Material\chatbot.pptx
# D:New folder\softwares\Anaconda3-2019.10-Windows-x86_64.exe
# D:New folder\softwares\CentOS-6.10-x86_64-bin-DVD1.iso
# D:New folder\softwares\CentOS-7-x86_64-DVD-1810.iso
# D:New folder\softwares\JavaSetup8u231.exe
# D:New folder\softwares\jdk-8u201-windows-x64.exe
# D:New folder\softwares\mysql-workbench-gpl-5.2.47-win32.msi
# D:New folder\softwares\putty.exe
# D:New folder\softwares\puttygen.exe
# D:New folder\softwares\python-3.7.4.exe
# D:New folder\softwares\R-3.6.1-win.exe
# D:New folder\softwares\RStudio-1.2.5001.exe
# D:New folder\softwares\spark-2.4.4-bin-hadoop2.6.tgz
# D:New folder\softwares\TableauDesktop-64bit-2019-4-0.exe
# D:New folder\softwares\VirtualBox-6.0.10-132072-Win.exe
# D:New folder\softwares\vmware key.txt
# D:New folder\softwares\VMware-workstation-full-15.0.4-12990004.exe
# D:New folder\softwares\Hadoop cluster\hadoop-2.6.0.tar.gz
# D:New folder\softwares\Hadoop cluster\Hadoop_Conf(1).doc
# D:New folder\softwares\Hadoop cluster\steps(1).txt
# D:New folder\softwares\Hadoop cluster\~$doop_Conf(1).doc
# D:New folder\softwares\HADOOP_virtual_machine original\Primary.vmdk
# D:New folder\softwares\HADOOP_virtual_machine original\Secondary.vmdk
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\564d374d-4025-a429-e902-ab3bc4eb3357.vmem
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\Primary.nvram
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\Primary.vmsd
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\Primary.vmx
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\Primary.vmxf
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\vmware-0.log
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\vmware-1.log
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\vmware-2.log
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\vmware.log
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\564d374d-4025-a429-e902-ab3bc4eb3357.vmem.lck\M65283.lck
# D:New folder\softwares\HADOOP_virtual_machine original\Primary\Primary.vmx.lck\M09464.lck
# D:New folder\softwares\HADOOP_virtual_machine original\Primary.vmdk.lck\M34073.lck
# D:New folder\softwares\HADOOP_virtual_machine original\secondary\secondary.nvram
# D:New folder\softwares\HADOOP_virtual_machine original\secondary\secondary.vmsd
# D:New folder\softwares\HADOOP_virtual_machine original\secondary\secondary.vmx
# D:New folder\softwares\HADOOP_virtual_machine original\secondary\secondary.vmxf
# D:New folder\softwares\HADOOP_virtual_machine original\secondary\vmware-0.log
# D:New folder\softwares\HADOOP_virtual_machine original\secondary\vmware.log
# D:New folder\softwares\MongoDB\GNU-AGPL-3.0
# D:New folder\softwares\MongoDB\mongo.txt
# D:New folder\softwares\MongoDB\mongod.cfg
# D:New folder\softwares\MongoDB\mongodb.rar
# D:New folder\softwares\MongoDB\README
# D:New folder\softwares\MongoDB\THIRD-PARTY-NOTICES
# D:New folder\softwares\MongoDB\bin\bsondump.exe
# D:New folder\softwares\MongoDB\bin\mongo.exe
# D:New folder\softwares\MongoDB\bin\mongod.exe
# D:New folder\softwares\MongoDB\bin\mongod.pdb
# D:New folder\softwares\MongoDB\bin\mongodump.exe
# D:New folder\softwares\MongoDB\bin\mongoexport.exe
# D:New folder\softwares\MongoDB\bin\mongofiles.exe
# D:New folder\softwares\MongoDB\bin\mongoimport.exe
# D:New folder\softwares\MongoDB\bin\mongooplog.exe
# D:New folder\softwares\MongoDB\bin\mongoperf.exe
# D:New folder\softwares\MongoDB\bin\mongorestore.exe
# D:New folder\softwares\MongoDB\bin\mongos.exe
# D:New folder\softwares\MongoDB\bin\mongos.pdb
# D:New folder\softwares\MongoDB\bin\mongostat.exe
# D:New folder\softwares\MongoDB\bin\mongotop.exe
# D:New folder\softwares\MongoDB\log\mongo.log
# D:New folder\softwares\MongoDB\log\mongo.log.2019-09-18T23-55-08
# D:New folder\softwares\MongoDB\log\mongo.log.2019-09-18T23-55-24
# D:New folder\softwares\MongoDB\log\mongo.log.2019-09-18T23-55-45
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\autorun.inf
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\readme.htm
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\setup.dll
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\setup.exe
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\access16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\excel16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\oct.dll
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\octca.dll
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\office16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\onent16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\outlk16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\ppt16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\proj16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\pub16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\spd16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\visio16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\word16.opax
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\access16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\excel16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\lync16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\octres.dll
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\office16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\onent16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\outlk16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\ppt16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\proj16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\pub16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\spd16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\visio16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\de-de\word16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\access16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\excel16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\octres.dll
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\office16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\onent16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\outlk16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\ppt16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\proj16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\pub16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\spd16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\visio16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\en-us\word16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\access16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\excel16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\lync16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\octres.dll
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\office16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\onent16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\outlk16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\ppt16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\proj16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\pub16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\spd16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\visio16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\es-es\word16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\access16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\excel16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\lync16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\octres.dll
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\office16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\onent16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\outlk16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\ppt16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\proj16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\pub16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\spd16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\visio16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\fr-fr\word16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\access16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\excel16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\lync16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\octres.dll
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\office16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\onent16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\outlk16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\ppt16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\proj16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\pub16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\spd16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\visio16.opal
# D:New folder\softwares\ms office 2016 standard\ms office 2016 standard\SW_DVD5_Office_2016_64Bit_English_MLF_X20-42479\admin\it-it\word16.opal
# ...
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-consumer-perf-test.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-delegation-tokens.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-delete-records.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-dump-log.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-log-dirs.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-mirror-maker.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-preferred-replica-election.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-producer-perf-test.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-reassign-partitions.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-replica-verification.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-run-class.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-server-start.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-server-stop.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\kafka-topics.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\zookeeper-server-start.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\zookeeper-server-stop.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\bin\windows\zookeeper-shell.bat
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\connect-console-sink.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\connect-console-source.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\connect-distributed.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\connect-file-sink.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\connect-file-source.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\connect-log4j.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\connect-standalone.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\consumer.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\log4j.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\producer.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\server.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\tools-log4j.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\trogdor.conf
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\config\zookeeper.properties
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\libs\activation-1.1.1.jar
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\libs\aopalliance-repackaged-2.5.0.jar
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\libs\argparse4j-0.7.0.jar
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\libs\audience-annotations-0.5.0.jar
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\libs\commons-lang3-3.8.1.jar
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\libs\connect-api-2.3.1.jar
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\libs\connect-basic-auth-extension-2.3.1.jar
# D:New folder\term 2\Spark\kafka_2.11-2.3.1\libs
# D:New folder\term 2\TABLEAU\Global Superstore 2016.xlsx
# D:New folder\term 2\TABLEAU\K-Nearest Neighbors.mp4
# D:New folder\term 2\TABLEAU\LOD.docx
# D:New folder\term 2\TABLEAU\MARKS.xlsx
# D:New folder\term 2\TABLEAU\Session 1 - CDAC Introduction to Visualization.ppt
# D:New folder\term 2\TABLEAU\Session 2 & 3 - CDAC Data Analytics Life Cycle -   Overview (1).ppt
# D:New folder\term 2\TABLEAU\Session 4 - CDAC Intelligent Data Analysis (1).ppt
# D:New folder\term 2\TABLEAU\tableau assignment 1.docx
# D:New folder\term 2\TABLEAU\tableau assignment 2.docx
# D:New folder\term 2\TABLEAU\tableau assignment 4.docx
# D:New folder\term 2\TABLEAU\tableau assignment 5.docx
# D:New folder\term 2\TABLEAU\tableauassignment3.docx
# D:New folder\term 2\TABLEAU\Tableaue PPT.pptx
# D:New folder\term 2\TABLEAU\which_chart_or_graph_v2.pdf
# D:New folder\term 2\TABLEAU\dataset_diabetes\diabetic_data.csv
# D:New folder\term 2\TABLEAU\dataset_diabetes\IDs_mapping.csv
# D:New folder\term 2\TABLEAU\tableau\18-12-19.twb
# D:New folder\term 2\TABLEAU\tableau\assi 2.twb
# D:New folder\term 2\TABLEAU\tableau\assi 3.twb
# D:New folder\term 2\TABLEAU\tableau\assi 4.twb
# D:New folder\term 2\TABLEAU\tableau\assi 5-1.twb
# D:New folder\term 2\TABLEAU\tableau\assi 5-2.twb
# D:New folder\term 2\TABLEAU\tableau\assi3.twb
# D:New folder\term 2\TABLEAU\tableau\Book1.twb
# D:New folder\term 2\TABLEAU\tableau\Book2.twb
# D:New folder\term 2\TABLEAU\tableau\Book3.twb
# D:New folder\term 2\TABLEAU\tableau\Book4.twb
# D:New folder\term 2\TABLEAU\tableau\charts in tableau.twb
# D:New folder\term 2\TABLEAU\tableau\plot.twb
# D:New folder\term 2\TABLEAU\tableau\ques3.twb
# D:New folder\term 2\TABLEAU\tableau\Thumbs.db
# D:New folder\term 2\TABLEAU\tableau\~assi 4__1064.twbr
# D:New folder\term 2\TABLEAU\Tableau lab test\tableau test.docx
# D:New folder\term 2\TABLEAU\Tableau lab test\~$bleau test.docx
# D:om\20020249.pdf
# D:om\BITSAT 2020 (Official).pdf
# D:om\IMG_20190911_222912_1568223843030.jpg
# D:om\IMG_20190911_223532 (1).jpg
# D:om\IMG_20190911_223532.jpg

# %%
zomato = pd.read_csv('D:/zomato.csv')
zomato.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc3 in position 32758: unexpected end of data
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-94b66963dde4> in <module>
# ----> 1 zomato = pd.read_csv('D:/zomato.csv')
#       2 zomato.head()
#
# E:\anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# E:\anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# E:\anaconda\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# E:\anaconda\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc3 in position 32758: unexpected end of data

# %%
zomato.shape

# %%
zomato.describe()

# %%
zomato.info()

# %%
#Checking the null values
zomato.isnull().sum()

# %%
#Removing the null values
zomato.dropna(how = 'any', inplace = True)

# %%
zomato.isnull().sum()

# %%
zomato.columns

# %%
#Dropping the columns which are not relevant
zomato=zomato.drop(['url','dish_liked','phone'],axis=1)

# %%
#Upadating few columns 
zomato = zomato.rename(columns={'approx_cost(for two people)':'cost','listed_in(type)':'type',
                                  'listed_in(city)':'city'})
zomato.columns

# %%
zomato.head()

# %%
#Checking for duplicate values
zomato.duplicated().sum()

# %%
#Dropping the duplicate values
zomato.drop_duplicates(inplace = True)

# %%
zomato.shape

# %%
#Simplifying the ratings column
#Removing '/5' from Rates
zomato['rate'].unique()
zomato = zomato.loc[zomato.rate !='NEW']
zomato = zomato.loc[zomato.rate !='-'].reset_index(drop=True)
remove_slash = lambda x: x.replace('/5', '') if type(x) == np.str else x
zomato.rate = zomato.rate.apply(remove_slash).str.strip().astype('float')

# %%
zomato['rate'].unique()

# %% [markdown]
# The highest rating to restaurants is 4.1 and the least rating to restaurants is 1.8.

# %% [markdown]
# ### Number of Restaurants in Area

# %%
rcParams['figure.figsize'] = (20,10)
sb.countplot(zomato['city'])
sb.countplot(zomato['city']).set_xticklabels(sb.countplot(zomato['city']).get_xticklabels(), rotation=90, ha="right")
plt.title('Number of Restaurants in Every Area', size = 20)
plt.show()

# %% [markdown]
# ### Restaurants taking Online Orders or Not

# %%
rcParams['figure.figsize'] = (10,10)
sb.countplot(zomato['online_order'])
plt.title('Count of Restaurants taking Online orders', size = 20)
plt.show()

# %% [markdown]
# ### Restaurants allowing Table Booking

# %%
rcParams['figure.figsize'] = (10,10)
sb.countplot(zomato['book_table'])
plt.title('Table Booking', size = 20)
plt.show()

# %% [markdown]
# ### Restaurant Type

# %%
rcParams['figure.figsize'] = (20,10)
sb.countplot(zomato['rest_type'])
sb.countplot(zomato['rest_type']).set_xticklabels(sb.countplot(zomato['rest_type']).get_xticklabels(), rotation=90, ha="right")
plt.title('Type of Restaurant', size = 20)
plt.show()

# %% [markdown]
# ### Type of Service

# %%
rcParams['figure.figsize'] = (20,10)
sb.countplot(zomato['type'])
sb.countplot(zomato['type']).set_xticklabels(sb.countplot(zomato['type']).get_xticklabels(), rotation=90, ha="right")
plt.title('Type of Service', size = 20)
plt.show()

# %% [markdown]
# ### Cost

# %%
rcParams['figure.figsize'] = (20,10)
sb.countplot(zomato['cost'])
sb.countplot(zomato['cost']).set_xticklabels(sb.countplot(zomato['cost']).get_xticklabels(), rotation=90, ha="right")
plt.title('Count of Restaurants based on Cost', size = 20)
plt.show()

# %% [markdown]
# ### Number of Restaurants in Every Location

# %%
rcParams['figure.figsize'] = (20,10)
sb.countplot(zomato['location'])
sb.countplot(zomato['location']).set_xticklabels(sb.countplot(zomato['location']).get_xticklabels(), rotation=90, ha="right")
plt.title('Count of Restaurant in Every Location', size = 20)
plt.show()

# %% [markdown]
# ### Top Restaurants in Bengaluru

# %%
rcParams['figure.figsize'] = (20,10)
top = zomato['name'].value_counts()[:20]
sb.barplot(x = top, y = top.index, palette = 'cool_r')
plt.xlabel("Number of outlets",size=15)
plt.title('Top 20 Restaurants', size = 20)
plt.show()

# %% [markdown]
# # Regression Analysis

# %%
zomato.head()

# %% [markdown]
# ### Some Transformations for Modelling

# %%
#Cost Transformations
zomato['cost'] = zomato['cost'].astype(str)
zomato['cost'] = zomato['cost'].apply(lambda x: x.replace(',','.'))
zomato['cost'] = zomato['cost'].astype(float)

# %%
zomato.cost.unique()

# %%
#Other Transformations
zomato.name = zomato.name.apply(lambda x:x.title())
zomato.online_order.replace(('Yes','No'),(True, False),inplace=True)
zomato.book_table.replace(('Yes','No'),(True, False),inplace=True)

# %% [markdown]
# ### Encoding

# %%
#Encoding of input Variables
def Encode(zomato):
    for column in zomato.columns[~zomato.columns.isin(['rate', 'cost', 'votes'])]:
        zomato[column] = zomato[column].factorize()[0]
    return zomato

zomato_en = Encode(zomato.copy())

# %% [markdown]
# ### Correlation Heatmap

# %%
rcParams['figure.figsize'] = (15,10)
sb.heatmap(zomato_en.corr(), annot=True)
plt.title('Correlation Heatmap', size = 20)
plt.show()

# %% [markdown]
# ### Modelling

# %%
#Defining the independent variables and dependent variables
x = zomato_en.iloc[:,[2,3,5,6,7,8,9,11]]
y = zomato_en['rate']

# %% [markdown]
# ### Splitting dataset for Training & Testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .2)

# %% [markdown]
# ### Random Forest Regression

# %%
#Preparing Random Forest Regression
from sklearn.ensemble import RandomForestRegressor
random = RandomForestRegressor(n_estimators=500)
random.fit(x_train,y_train)

# %%
print(" Accuracy :{}" .format(random.score(x_test, y_test)))

# %% [markdown]
# # Sentiment Analysis

# %%
# Importing Intensity Analyser to check the intensity status of the given review
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Selecting 5 sample reviews to analyse the intensity
restaurant_rev = zomato['reviews_list'].value_counts()
restaurant_rev.sample(5)

# %%
# Picking random reviews from the samples to analyse
# fitting the review as sentence for analysis
rev = ["Best place to take your family or the one you have a comfortable relationship with. A no-frills place serving good quality but not extraordinary food.",
      "Awesome place with good ambience and service food was superb , rabbidi was finger licking... A must try ",
      "Visited this place for lunch.. we opted ala carte.. let me remind you the place is quite expensive for the amount it serves. We ordered 2 naan, one malai kofta, 2 shikanji and the bill was 1250 bucks.",
      "I really did not like it.. it is far from fine dining.. it will just burn a hole in your pocket for no reason.",
      "I love the food, but when it comes cleanliness it is zero. Take away is good. But being a budget friendly place, i love it. I am not saying the food is amazing , but yeah it is good. They definitely need a revamp."]

# %%
sid = SentimentIntensityAnalyzer()
for sentence in rev:
    print(sentence)
    ss = sid.polarity_scores(sentence)
    for k in ss:
        print('{0}: {1}, '.format(k, ss[k]), end = '\n')
    print()
